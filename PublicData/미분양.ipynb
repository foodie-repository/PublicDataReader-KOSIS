# %% [markdown]
# # KOSIS 아파트 미분양 현황 데이터 수집 및 분석
#
# 이 노트북은 PublicDataReader 라이브러리를 사용하여 국토교통부의 시군구별 아파트 미분양 현황 데이터를 수집하고 분석합니다.
#
# **데이터 범위:**
# - 기간: 2007년 1월 ~ 2025년 12월 (최신월까지)
# - 지역: 전국 시도별 + 시군구별 (215개 시군구)
# - 주택유형: 아파트 미분양 (주택유형 구분 없음)

# %% [markdown]
# ## 1. 라이브러리 Import

# %%
from PublicDataReader import Kosis
import pandas as pd
from datetime import datetime

# 그래프 라이브러리 (Plotly 사용)
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Plotly 기본 설정
import plotly.io as pio
pio.templates.default = "plotly_white"

print("✓ 라이브러리 Import 완료")
print("✓ Plotly 인터랙티브 그래프 사용")
# Out:
# ✓ 라이브러리 Import 완료
# ✓ Plotly 인터랙티브 그래프 사용

# %% [markdown]
# ## 2. 데이터 수집 함수 정의

# %%
# 미분양.py에서 collect_unsold_data 함수를 그대로 가져옴
exec(open('미분양.py', encoding='utf-8').read())
# Out:
# ==================================================
# KOSIS 아파트 미분양 현황 데이터 수집 시작
# ==================================================
# KOSIS API 인스턴스 생성 완료
# 데이터 수집 시작: 200701 ~ 202512
# 총 17개 지역 x 3개 기간으로 나누어 수집합니다.
#
# [1/51] 서울 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1520건
#
# [2/51] 서울 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1829건
#
# [3/51] 서울 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1805건
#
# [4/51] 부산 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1224건
#
# [5/51] 부산 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1214건
#
# [6/51] 부산 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1393건
#
# [7/51] 대구 (2007-2012) 수집 중...
#   ✓ 수집 완료: 648건
#
# [8/51] 대구 (2013-2018) 수집 중...
#   ✓ 수집 완료: 631건
#
# [9/51] 대구 (2019-2025) 수집 중...
#   ✓ 수집 완료: 764건
#
# [10/51] 인천 (2007-2012) 수집 중...
#   ✓ 수집 완료: 778건
#
# [11/51] 인천 (2013-2018) 수집 중...
#   ✓ 수집 완료: 767건
#
# [12/51] 인천 (2019-2025) 수집 중...
#   ✓ 수집 완료: 899건
#
# [13/51] 광주 (2007-2012) 수집 중...
#   ✓ 수집 완료: 432건
#
# [14/51] 광주 (2013-2018) 수집 중...
#   ✓ 수집 완료: 430건
#
# [15/51] 광주 (2019-2025) 수집 중...
#   ✓ 수집 완료: 490건
#
# [16/51] 대전 (2007-2012) 수집 중...
#   ✓ 수집 완료: 432건
#
# [17/51] 대전 (2013-2018) 수집 중...
#   ✓ 수집 완료: 431건
#
# [18/51] 대전 (2019-2025) 수집 중...
#   ✓ 수집 완료: 491건
#
# [19/51] 울산 (2007-2012) 수집 중...
#   ✓ 수집 완료: 432건
#
# [20/51] 울산 (2013-2018) 수집 중...
#   ✓ 수집 완료: 432건
#
# [21/51] 울산 (2019-2025) 수집 중...
#   ✓ 수집 완료: 492건
#
# [22/51] 경기 (2007-2012) 수집 중...
#   ✓ 수집 완료: 2253건
#
# [23/51] 경기 (2013-2018) 수집 중...
#   ✓ 수집 완료: 2256건
#
# [24/51] 경기 (2019-2025) 수집 중...
#   ✓ 수집 완료: 2619건
#
# [25/51] 강원 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1321건
#
# [26/51] 강원 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1358건
#
# [27/51] 강원 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1555건
#
# [28/51] 충북 (2007-2012) 수집 중...
#   ✓ 수집 완료: 936건
#
# [29/51] 충북 (2013-2018) 수집 중...
#   ✓ 수집 완료: 863건
#
# [30/51] 충북 (2019-2025) 수집 중...
#   ✓ 수집 완료: 980건
#
# [31/51] 충남 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1224건
#
# [32/51] 충남 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1159건
#
# [33/51] 충남 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1310건
#
# [34/51] 전북 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1027건
#
# [35/51] 전북 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1045건
#
# [36/51] 전북 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1225건
#
# [37/51] 전남 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1544건
#
# [38/51] 전남 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1584건
#
# [39/51] 전남 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1866건
#
# [40/51] 경북 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1515건
#
# [41/51] 경북 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1661건
#
# [42/51] 경북 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1929건
#
# [43/51] 경남 (2007-2012) 수집 중...
#   ✓ 수집 완료: 1426건
#
# [44/51] 경남 (2013-2018) 수집 중...
#   ✓ 수집 완료: 1341건
#
# [45/51] 경남 (2019-2025) 수집 중...
#   ✓ 수집 완료: 1554건
#
# [46/51] 제주 (2007-2012) 수집 중...
#   ✓ 수집 완료: 216건
#
# [47/51] 제주 (2013-2018) 수집 중...
#   ✓ 수집 완료: 216건
#
# [48/51] 제주 (2019-2025) 수집 중...
#   ✓ 수집 완료: 246건
#
# [49/51] 세종 (2007-2012) 수집 중...
#   ✓ 수집 완료: 12건
#
# [50/51] 세종 (2013-2018) 수집 중...
#   ✓ 수집 완료: 139건
#
# [51/51] 세종 (2019-2025) 수집 중...
#   ✓ 수집 완료: 162건
#
# 데이터 수집 완료! 총 54,076건의 데이터가 수집되었습니다.
#
# ==================================================
# 데이터 정보
# ==================================================
#
# 전체 데이터 건수: 54,076건
# 컬럼 목록: 기관ID, 통계표ID, 통계표명, 분류명1, 분류영문명1, 분류값명1, 분류값ID1, 분류명2, 분류영문명2, 분류값명2, 분류값영문명2, 분류값ID2, 항목ID, 항목명, 항목영문명, 단위명, 단위영문명, 수록주기, 수록시점, 수치값, LST_CHN_DE, 분류값영문명1
#
# [지역별 데이터 건수]
#   - 경기: 7,128건
#   - 서울: 5,154건
#   - 경북: 5,105건
#   - 전남: 4,994건
#   - 경남: 4,321건
#   - 강원: 4,234건
#   - 부산: 3,831건
#   - 충남: 3,693건
#   - 전북: 3,297건
#   - 충북: 2,779건
#   - 인천: 2,444건
#   - 대구: 2,043건
#   - 울산: 1,356건
#   - 대전: 1,354건
#   - 광주: 1,352건
#   - 제주: 678건
#   - 세종: 313건
#
# [수집 기간]
#   - 시작: 200701
#   - 종료: 202510
#
# [시군구 개수]
#   - 전체: 215개
#
# [데이터 샘플 (상위 5건)]
#   기관ID          통계표ID               통계표명 분류명1   분류영문명1 분류값명1  \
# 0  101  DT_1YL202004E  미분양주택현황(시도/시/군/구)   구분  SiGunGu    서울
# 1  101  DT_1YL202004E  미분양주택현황(시도/시/군/구)   구분  SiGunGu    서울
# 2  101  DT_1YL202004E  미분양주택현황(시도/시/군/구)   구분  SiGunGu    서울
# 3  101  DT_1YL202004E  미분양주택현황(시도/시/군/구)   구분  SiGunGu    서울
# 4  101  DT_1YL202004E  미분양주택현황(시도/시/군/구)   구분  SiGunGu    서울
#
#               분류값ID1 분류명2   분류영문명2 분류값명2  ...           항목ID    항목명  \
# 0  13102871087A.0002  시군구  SiGunGu     계  ...  13103871087T1  미분양현황
# 1  13102871087A.0002  시군구  SiGunGu     계  ...  13103871087T1  미분양현황
# 2  13102871087A.0002  시군구  SiGunGu     계  ...  13103871087T1  미분양현황
# 3  13102871087A.0002  시군구  SiGunGu     계  ...  13103871087T1  미분양현황
# 4  13102871087A.0002  시군구  SiGunGu     계  ...  13103871087T1  미분양현황
#
#             항목영문명 단위명  단위영문명 수록주기    수록시점  수치값 LST_CHN_DE  분류값영문명1
# 0  Unsold Housing   호  House    M  200701  697                 NaN
# 1  Unsold Housing   호  House    M  200702  590                 NaN
# 2  Unsold Housing   호  House    M  200703  687                 NaN
# 3  Unsold Housing   호  House    M  200704  685                 NaN
# 4  Unsold Housing   호  House    M  200705  704                 NaN
#
# [5 rows x 22 columns]
#
# ==================================================
# 데이터가 '미분양현황_시군구별_20251227.csv' 파일로 저장되었습니다.
#
# === 최종 피벗 테이블 생성 중 ===
# 수집 기간: 200701 ~ 202510
# 최종 피벗 테이블이 '미분양현황_피벗_전체기간_최종.csv' 파일로 저장되었습니다.
# - 총 50,303개 행 (226개 시점 x 17개 시도 x 시군구별)
#
# 모든 작업이 완료되었습니다!

# %% [markdown]
# ## 3. 데이터 수집 실행 (선택사항)
#
# **주의:** 이 셀을 실행하면 KOSIS API로부터 데이터를 새로 수집합니다 (약 3-5분 소요).
# 이미 수집된 CSV 파일이 있다면 다음 셀에서 파일을 직접 로드하세요.

# %%
# 새로 데이터 수집
df_raw = collect_unsold_data()

if df_raw is not None:
    # 원본 데이터 저장
    current_date = datetime.now().strftime("%Y%m%d")
    df_raw.to_csv(f"미분양현황_시군구별_{current_date}.csv", index=False, encoding='utf-8-sig')
    print(f"원본 데이터가 '미분양현황_시군구별_{current_date}.csv' 파일로 저장되었습니다.")

# %% [markdown]
# ## 4. 기존 데이터 로드 (선택사항)
#
# 이미 수집된 CSV 파일을 로드합니다.

# %%
# 기존 원본 데이터 로드
df_raw = pd.read_csv('미분양현황_시군구별_20251227.csv', encoding='utf-8-sig')
print(f"원본 데이터 로드 완료: {len(df_raw):,}건")
print(f"수집 기간: {df_raw['수록시점'].min()} ~ {df_raw['수록시점'].max()}")
# Out:
# 원본 데이터 로드 완료: 54,076건
# 수집 기간: 200701 ~ 202510

# %% [markdown]
# ## 5. 최종 피벗 테이블 생성

# %%
# 최종 피벗 테이블 생성
df_final = create_final_pivot_table(df_raw)

# 데이터 확인
print("\n=== 최종 데이터 미리보기 ===")
display(df_final.head(20))

print("\n=== 데이터 통계 ===")
print(f"총 행 수: {len(df_final):,}")
print(f"시점 범위: {df_final['시점'].min()} ~ {df_final['시점'].max()}")
print(f"시도 개수: {len(df_final['시도'].unique())}개")
print(f"시군구 개수: {len(df_final['시군구'].unique())}개")
print(f"시도 목록: {', '.join(sorted(df_final['시도'].unique()))}")
# Out:
# === 최종 피벗 테이블 생성 중 ===
# 수집 기간: 200701 ~ 202510
# 최종 피벗 테이블이 '미분양현황_피벗_전체기간_최종.csv' 파일로 저장되었습니다.
# - 총 50,303개 행 (226개 시점 x 17개 시도 x 시군구별)
#
# === 최종 데이터 미리보기 ===
#          시점     시도  시군구  미분양수
# 72  2007.05  서울특별시  종로구    19
# 73  2007.06  서울특별시  종로구    93
# 74  2007.07  서울특별시  종로구    89
# 75  2007.08  서울특별시  종로구    89
# 76  2007.09  서울특별시  종로구    89
# 77  2007.10  서울특별시  종로구    89
# 78  2007.11  서울특별시  종로구    81
# 79  2007.12  서울특별시  종로구    73
# 80  2008.01  서울특별시  종로구    73
# 81  2008.02  서울특별시  종로구    67
# 82  2008.03  서울특별시  종로구    64
# 83  2008.04  서울특별시  종로구    62
# 84  2008.05  서울특별시  종로구    61
# 85  2008.06  서울특별시  종로구    51
# 86  2008.07  서울특별시  종로구    48
# 87  2008.08  서울특별시  종로구    48
# 88  2008.09  서울특별시  종로구    46
# 89  2008.10  서울특별시  종로구    46
# 90  2008.11  서울특별시  종로구    45
# 91  2008.12  서울특별시  종로구    46
# === 데이터 통계 ===
# 총 행 수: 50,303
# 시점 범위: 2007.01 ~ 2025.10
# 시도 개수: 17개
# 시군구 개수: 214개
# 시도 목록: 강원특별자치도, 경기도, 경상남도, 경상북도, 광주광역시, 대구광역시, 대전광역시, 부산광역시, 서울특별시, 세종특별자치시, 울산광역시, 인천광역시, 전라남도, 전북특별자치도, 제주특별자치도, 충청남도, 충청북도

# %% [markdown]
# ## 6. 데이터 탐색

# %%
# 특정 시도의 데이터 확인
sido_name = '서울특별시'
df_seoul = df_final[df_final['시도'] == sido_name]

print(f"\n=== {sido_name} 데이터 ===")
display(df_seoul.head(20))

# 시군구별 총 미분양 (2007-2025)
print(f"\n=== {sido_name} 시군구별 총 미분양 수 (2007-2025) ===")
sigungu_total = df_seoul.groupby('시군구')['미분양수'].sum().sort_values(ascending=False)
display(sigungu_total.head(10))
# Out:
# === 서울특별시 데이터 ===
#          시점     시도  시군구  미분양수
# 72  2007.05  서울특별시  종로구    19
# 73  2007.06  서울특별시  종로구    93
# 74  2007.07  서울특별시  종로구    89
# 75  2007.08  서울특별시  종로구    89
# 76  2007.09  서울특별시  종로구    89
# 77  2007.10  서울특별시  종로구    89
# 78  2007.11  서울특별시  종로구    81
# 79  2007.12  서울특별시  종로구    73
# 80  2008.01  서울특별시  종로구    73
# 81  2008.02  서울특별시  종로구    67
# 82  2008.03  서울특별시  종로구    64
# 83  2008.04  서울특별시  종로구    62
# 84  2008.05  서울특별시  종로구    61
# 85  2008.06  서울특별시  종로구    51
# 86  2008.07  서울특별시  종로구    48
# 87  2008.08  서울특별시  종로구    48
# 88  2008.09  서울특별시  종로구    46
# 89  2008.10  서울특별시  종로구    46
# 90  2008.11  서울특별시  종로구    45
# 91  2008.12  서울특별시  종로구    46
# === 서울특별시 시군구별 총 미분양 수 (2007-2025) ===
# 시군구
# 강동구     34295
# 동작구     27915
# 마포구     27179
# 서대문구    20765
# 성북구     16669
# 구로구     15200
# 성동구     12264
# 양천구     11102
# 용산구      9748
# 강서구      9613
# Name: 미분양수, dtype: int64

# %% [markdown]
# ## 7. 시각화
#
# ### 7.1. 전국 아파트 미분양 추이

# %%
# 시점을 datetime으로 변환
df_final['시점_dt'] = pd.to_datetime(df_final['시점'], format='%Y.%m')

# 전국 월별 미분양 합계 (시군구 '계'만 사용)
df_monthly_total = df_final[df_final['시군구'] == '계'].groupby('시점_dt')['미분양수'].sum().reset_index()

# 그래프 생성
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=df_monthly_total['시점_dt'],
        y=df_monthly_total['미분양수'],
        mode='lines+markers',
        name='전국 미분양',
        line=dict(width=2, color='#E74C3C'),
        marker=dict(size=4),
        hovertemplate='%{x|%Y.%m}<br>미분양: %{y:,.0f}호<extra></extra>'
    )
)

# X축 설정
fig.update_xaxes(
    title_text='시점',
    tickangle=-90,
    dtick="M12"
)

# Y축 설정
fig.update_yaxes(
    title_text='미분양 수(호)',
    tickformat=","
)

# 레이아웃 설정
fig.update_layout(
    title='전국 아파트 미분양 추이 (2007-2025)',
    title_font_size=16,
    height=500,
    hovermode='x unified',
    font=dict(size=12)
)

fig.show()

# %% [markdown]
# ### 7.2. 시도별 미분양 비교 (최근 1년)

# %%
# 최근 1년 데이터 필터링
latest_date = df_final['시점_dt'].max()
one_year_ago = latest_date - pd.DateOffset(months=12)
df_recent = df_final[df_final['시점_dt'] > one_year_ago]

# 시도별 '계' 데이터만 사용하여 합계 계산
df_sido_total = df_recent[df_recent['시군구'] == '계'].groupby('시도')['미분양수'].sum().reset_index()
df_sido_total = df_sido_total.sort_values('미분양수', ascending=True)

# 가로 막대 그래프
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df_sido_total['미분양수'],
    y=df_sido_total['시도'],
    orientation='h',
    marker=dict(color='#E74C3C'),
    text=df_sido_total['미분양수'].apply(lambda x: f'{x:,.0f}'),
    textposition='inside',
    textfont=dict(color='white'),
    hovertemplate='%{y}<br>미분양: %{x:,.0f}호<extra></extra>'
))

# X축 설정
fig.update_xaxes(tickformat=",")

# 레이아웃 설정
fig.update_layout(
    title=f'시도별 아파트 미분양 현황 (최근 1년: {one_year_ago.strftime("%Y.%m")} ~ {latest_date.strftime("%Y.%m")})',
    xaxis_title='미분양 수(호)',
    yaxis_title='시도',
    height=600,
    font=dict(size=12)
)

fig.show()

# %% [markdown]
# ### 7.3. 시군구별 미분양 Top 20 (최근 1개월)

# %%
# 최근 1개월 데이터
df_latest_month = df_final[df_final['시점_dt'] == latest_date]

# 시군구 '계' 제외하고 Top 20
df_sigungu_top = df_latest_month[df_latest_month['시군구'] != '계'].nlargest(20, '미분양수')
df_sigungu_top = df_sigungu_top.sort_values('미분양수', ascending=True)

# 시도+시군구 합치기
df_sigungu_top['지역'] = df_sigungu_top['시도'].str.replace('특별시|광역시|특별자치시|특별자치도|도', '', regex=True) + ' ' + df_sigungu_top['시군구']

# 가로 막대 그래프
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df_sigungu_top['미분양수'],
    y=df_sigungu_top['지역'],
    orientation='h',
    marker=dict(color=df_sigungu_top['미분양수'], colorscale='Reds'),
    text=df_sigungu_top['미분양수'].apply(lambda x: f'{x:,.0f}'),
    textposition='inside',
    textfont=dict(color='white'),
    hovertemplate='%{y}<br>미분양: %{x:,.0f}호<extra></extra>'
))

# X축 설정
fig.update_xaxes(tickformat=",")

# 레이아웃 설정
fig.update_layout(
    title=f'시군구별 아파트 미분양 Top 20 ({latest_date.strftime("%Y.%m")})',
    xaxis_title='미분양 수(호)',
    yaxis_title='지역',
    height=700,
    font=dict(size=11),
    showlegend=False
)

fig.show()

# %% [markdown]
# ### 7.4. 특정 시도의 미분양 추이

# %%
# 사용자로부터 시도 입력 받기
print("시도 정식 명칭을 입력하세요. (예: 서울특별시, 세종특별자치시, 전북특별자치도)")
print(f"\n사용 가능한 시도:")
for sido in sorted(df_final['시도'].unique()):
    print(f"  - {sido}")

target_sido = input("\n시도 입력: ")

# 입력된 시도가 유효한지 확인
if target_sido not in df_final['시도'].unique():
    print(f"\n⚠️ '{target_sido}'는 데이터에 없습니다.")
    print(f"사용 가능한 시도: {', '.join(sorted(df_final['시도'].unique()))}")
else:
    # 해당 시도의 '계' 데이터만 추출
    df_sido = df_final[(df_final['시도'] == target_sido) & (df_final['시군구'] == '계')]
    
    # 그래프 생성
    fig = go.Figure()
    
    fig.add_trace(
        go.Scatter(
            x=df_sido['시점_dt'],
            y=df_sido['미분양수'],
            mode='lines+markers',
            name=target_sido,
            line=dict(width=2, color='#3498DB'),
            marker=dict(size=4),
            hovertemplate='%{x|%Y.%m}<br>미분양: %{y:,.0f}호<extra></extra>'
        )
    )
    
    # X축 설정
    fig.update_xaxes(
        title_text='시점',
        tickangle=-90,
        dtick="M12"
    )
    
    # Y축 설정
    fig.update_yaxes(
        title_text='미분양 수(호)',
        tickformat=","
    )
    
    # 레이아웃 설정
    fig.update_layout(
        title=f'{target_sido} 아파트 미분양 추이 (2007-2025)',
        title_font_size=16,
        height=500,
        hovermode='x unified',
        font=dict(size=12)
    )
    
    fig.show()
    print(f"\n✓ {target_sido} 그래프가 생성되었습니다.")
# Out:
# 시도 정식 명칭을 입력하세요. (예: 서울특별시, 세종특별자치시, 전북특별자치도)
#
# 사용 가능한 시도:
#   - 강원특별자치도
#   - 경기도
#   - 경상남도
#   - 경상북도
#   - 광주광역시
#   - 대구광역시
#   - 대전광역시
#   - 부산광역시
#   - 서울특별시
#   - 세종특별자치시
#   - 울산광역시
#   - 인천광역시
#   - 전라남도
#   - 전북특별자치도
#   - 제주특별자치도
#   - 충청남도
#   - 충청북도
# ✓ 경기도 그래프가 생성되었습니다.

# %% [markdown]
# ### 7.5. 시도별 미분양 추이 비교

# %%
# 각 시도별 '계' 데이터만 추출
df_sido_time = df_final[df_final['시군구'] == '계']

# 그래프 생성
fig = px.line(
    df_sido_time,
    x='시점_dt',
    y='미분양수',
    color='시도',
    title='시도별 아파트 미분양 추이 비교 (2007-2025)',
    labels={'시점_dt': '시점', '미분양수': '미분양 수(호)'},
    height=600
)

# 레이아웃 설정
fig.update_layout(
    hovermode='x unified',
    font=dict(size=12),
    legend=dict(
        orientation="v",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.02
    )
)

# X축 설정
fig.update_xaxes(tickangle=-90)

# Y축 설정
fig.update_yaxes(tickformat=",")

fig.show()

# %% [markdown]
# ## 8. 추가 분석 영역
#
# 아래 셀에 추가 분석 및 시각화 코드를 작성하세요.

# %%
# 추가 분석 코드를 여기에 작성하세요
